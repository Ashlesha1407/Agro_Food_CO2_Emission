# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings("ignore")

# %%
agro = pd.read_csv("C:\\Users\\ashle\\Desktop\\Personal Project\\Agrofood_co2_emission.csv")
agro
# Out:
#                     Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0     Russian Federation  2002      5256.5323     4398.4483      6191.9035
# 1     Russian Federation  2001      4154.2234     3261.0644      6094.7651
# 2     Russian Federation  2003      9923.4229     7774.0919      4904.1099
# 3     Russian Federation  2004      2395.6344     7925.6117      5594.0945
# 4     Russian Federation  2005      3597.2933     3782.1462      5637.7995
# ...                  ...   ...            ...           ...            ...
# 6960     China, mainland  2019       253.5691      654.1619     33102.4711
# 6961               China  2018       209.3065      668.9525     33104.1788
# 6962               China  2019       253.5825      654.1619     33209.1044
# 6963     China, mainland  2020       163.8876      603.8159     33384.8108
# 6964               China  2020       163.8876      603.8159     33490.0741
#
# ...

# %%
#Top 10
agro.head(10)
# Out:
#                  Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Russian Federation  2002      5256.5323     4398.4483      6191.9035
# 1  Russian Federation  2001      4154.2234     3261.0644      6094.7651
# 2  Russian Federation  2003      9923.4229     7774.0919      4904.1099
# 3  Russian Federation  2004      2395.6344     7925.6117      5594.0945
# 4  Russian Federation  2005      3597.2933     3782.1462      5637.7995
# 5  Russian Federation  2009      3679.5756     4746.6895      6740.1242
# 6  Russian Federation  2006      3965.0254     5980.0165      5602.5815
# 7  Russian Federation  2007      3199.4897     3052.3239      5766.3450
# 8  Russian Federation  2010      4843.6536     5972.4142      4501.8805
# 9  Russian Federation  2008      6583.8158    11381.6188      7329.0993
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0         1019.9840                   51191.7382                     771.0
# ...

# %%
#Bottom 10 
agro.tail(10)
# Out:
#                  Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 6955            China  2014       334.4457      620.0518     30638.5338
# 6956  China, mainland  2017       160.5455      308.1398     33277.0413
# 6957            China  2016       204.5083      580.8440     33187.8780
# 6958  China, mainland  2018       209.0857      668.9525     32991.2526
# 6959            China  2017       160.5455      308.1398     33382.8569
# 6960  China, mainland  2019       253.5691      654.1619     33102.4711
# 6961            China  2018       209.3065      668.9525     33104.1788
# 6962            China  2019       253.5825      654.1619     33209.1044
# 6963  China, mainland  2020       163.8876      603.8159     33384.8108
# 6964            China  2020       163.8876      603.8159     33490.0741
#
#       Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 6955       150434.3050                    3853.1141                   11443.0
# ...

# %%
# Information of dataset
agro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area                             6965 non-null   object
#  1   Year                             6965 non-null   int64
#  2   Savanna fires                    6934 non-null   float64
#  3   Forest fires                     6872 non-null   float64
#  4   Crop Residues                    5576 non-null   float64
#  5   Rice Cultivation                 6965 non-null   float64
#  6   Drained organic soils (CO2)      6965 non-null   float64
#  7   Pesticides Manufacturing         6965 non-null   float64
#  8   Food Transport                   6965 non-null   float64
#  9   Forestland                       6472 non-null   float64
#  10  Net Forest conversion            6472 non-null   float64
# ...

# %%
#Detailed description of dataset
agro.describe()
# Out:
#               Year  Savanna fires  Forest fires  Crop Residues  \
# count  6965.000000    6934.000000   6872.000000    5576.000000
# mean   2005.124910    1188.390893    919.302167     998.706309
# std       8.894665    5246.287783   3720.078752    3700.345330
# min    1990.000000       0.000000      0.000000       0.000200
# 25%    1997.000000       0.000000      0.000000      11.006525
# 50%    2005.000000       1.651850      0.517900     103.698200
# 75%    2013.000000     111.081400     64.950775     377.640975
# max    2020.000000  114616.401100  52227.630600   33490.074100
#
#        Rice Cultivation  Drained organic soils (CO2)  \
# count       6965.000000                  6965.000000
# mean        4259.666673                  3503.228636
# std        17613.825187                 15861.445678
# min            0.000000                     0.000000
# 25%          181.260800                     0.000000
# 50%          534.817400                     0.000000
# ...

# %%
# To check unique values in datatset
agro.nunique()
# Out:
# Area                                236
# Year                                 31
# Savanna fires                      3746
# Forest fires                       2962
# Crop Residues                      5358
# Rice Cultivation                   3635
# Drained organic soils (CO2)        2147
# Pesticides Manufacturing           1310
# Food Transport                     6512
# Forestland                          605
# Net Forest conversion               442
# Food Household Consumption         6358
# Food Retail                        6459
# On-farm Electricity Use            5322
# Food Packaging                     3704
# Agrifood Systems Waste Disposal    6419
# Food Processing                    3542
# Fertilizers Manufacturing          2973
# IPPU                               6026
# Manure applied to Soils            5927
# Manure left on Pasture             5922
# Manure Management                  5931
# Fires in organic soils              126
# ...

# %%
# Check null values in dataset
agro.isnull().sum()
# Out:
# Area                                  0
# Year                                  0
# Savanna fires                        31
# Forest fires                         93
# Crop Residues                      1389
# Rice Cultivation                      0
# Drained organic soils (CO2)           0
# Pesticides Manufacturing              0
# Food Transport                        0
# Forestland                          493
# Net Forest conversion               493
# Food Household Consumption          473
# Food Retail                           0
# On-farm Electricity Use               0
# Food Packaging                        0
# Agrifood Systems Waste Disposal       0
# Food Processing                       0
# Fertilizers Manufacturing             0
# IPPU                                743
# Manure applied to Soils             928
# Manure left on Pasture                0
# Manure Management                   928
# Fires in organic soils                0
# ...

# %%
# Calculate the total percentage of null values in dataset
l=(agro.isnull().sum()/(len(agro)))*100
l
# Out:
# Area                                0.000000
# Year                                0.000000
# Savanna fires                       0.445083
# Forest fires                        1.335248
# Crop Residues                      19.942570
# Rice Cultivation                    0.000000
# Drained organic soils (CO2)         0.000000
# Pesticides Manufacturing            0.000000
# Food Transport                      0.000000
# Forestland                          7.078248
# Net Forest conversion               7.078248
# Food Household Consumption          6.791098
# Food Retail                         0.000000
# On-farm Electricity Use             0.000000
# Food Packaging                      0.000000
# Agrifood Systems Waste Disposal     0.000000
# Food Processing                     0.000000
# Fertilizers Manufacturing           0.000000
# IPPU                               10.667624
# Manure applied to Soils            13.323762
# Manure left on Pasture              0.000000
# ...

# %%
#Drop the columns with maxiumum null values
agro1 = agro.drop(['Crop Residues','Manure applied to Soils','Manure Management','On-farm energy use'], axis = 1)
agro1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area                             6965 non-null   object
#  1   Year                             6965 non-null   int64
#  2   Savanna fires                    6934 non-null   float64
#  3   Forest fires                     6872 non-null   float64
#  4   Rice Cultivation                 6965 non-null   float64
#  5   Drained organic soils (CO2)      6965 non-null   float64
#  6   Pesticides Manufacturing         6965 non-null   float64
#  7   Food Transport                   6965 non-null   float64
#  8   Forestland                       6472 non-null   float64
#  9   Net Forest conversion            6472 non-null   float64
#  10  Food Household Consumption       6492 non-null   float64
# ...

# %%
# Plotting EDA 
sns.boxplot(data= agro1)
plt.show()
